# %%
text = '문자열-나누기'
li = text.split(sep='-')    # -가 나오는 부분을 기준으로 문자열을 리스트로 나눔
li
# Out:
# ['문자열', '나누기']

# %%
text2 = '-'.join(li)    #join 함수로 리스트 요소 하나하나를 합쳐서 문자열로 바꿈
text2
# Out:
# '문자열-나누기'

# %%
alist = {
    '키1' : ['값1','값2'],
    '키2' : ['값3','값4'],
    '키3' : ['값5','값6'],
    '키4' : {'키':100}
}
print(list(alist['키1']))
print(alist['키4']['키'])
# Out:
# ['값1', '값2']
# 100

# %%
team_dic = {'승혜':['러닝',70,25,20],'유진':['드라마보기',60,25,25],'지현':['노래듣기',65,23,21],'창익':['당구',60,27,17],'혜원':['인터넷쇼핑하기',70,28,28],'영은':['책읽기랑운동하기',95,25,20],'지선':['카페가기',90,23,23]}
a = input()
b_list = team_dic[a]
print(f'우리 {a}님은 {b_list[0]}을 좋아해요')
print(f'체력은 {b_list[1]}! {b_list[2]}세의 신체연령에 신기하게도 정신연령은 {b_list[3]}세!')
print(f'사랑스러운 {a}님이시네요')
# Out:
# 창익
# 우리 창익님은 당구을 좋아해요
# 체력은 60! 27세의 신체연령에 신기하게도 정신연령은 17세!
# 사랑스러운 창익님이시네요

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
files = {'image':open('/content/drive/MyDrive/Colab Notebooks/얼굴.png')}

# %%
import json
result = json.loads(response.text)
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c5ca6a655fd8> in <module>()
#       1 import json
# ----> 2 result = json.loads(response.text)
#       3 result
#
# NameError: name 'response' is not defined

# %%
import os
import sys
import requests

# 등록된 client_id, client_secret 정보를 입력합니다.
client_id = "yBwPM0bgoQTE7MzqhxmM"
client_secret = "2HiUBFvSq_"

# 얼굴 사진을 통한 나이 추정을 위해서는 아래 url을 사용합니다. (face: 얼굴 분석, celebrity: 닮은 유명인 찾기)
url = "https://openapi.naver.com/v1/vision/face" 
# url = "https://openapi.naver.com/v1/vision/celebrity" 

# 분석할 이미지의 파일명을 입력합니다./
files = {'image': open('/content/drive/MyDrive/Colab Notebooks/얼굴.png', 'rb')}

# API 입력 설정
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# API 사용
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code

if (rescode==200):
    # 결과물 출력
    print (response.text)
else:
    print("Error Code:" + str(rescode))

import json
result = json.loads(response.text)
result
# Out:
# {"info":{"size":{"width":487,"height":495},"faceCount":1},"faces":[{"roi":{"x":148,"y":147,"width":220,"height":220},"landmark":{"leftEye":{"x":193,"y":195},"rightEye":{"x":307,"y":202},"nose":{"x":254,"y":262},"leftMouth":{"x":207,"y":333},"rightMouth":{"x":297,"y":330}},"gender":{"value":"male","confidence":0.998573},"age":{"value":"22~26","confidence":0.279938},"emotion":{"value":"neutral","confidence":0.978082},"pose":{"value":"frontal_face","confidence":0.998387}}]}
# {'faces': [{'age': {'confidence': 0.279938, 'value': '22~26'},
#    'emotion': {'confidence': 0.978082, 'value': 'neutral'},
#    'gender': {'confidence': 0.998573, 'value': 'male'},
#    'landmark': {'leftEye': {'x': 193, 'y': 195},
#     'leftMouth': {'x': 207, 'y': 333},
#     'nose': {'x': 254, 'y': 262},
#     'rightEye': {'x': 307, 'y': 202},
#     'rightMouth': {'x': 297, 'y': 330}},
#    'pose': {'confidence': 0.998387, 'value': 'frontal_face'},
#    'roi': {'height': 220, 'width': 220, 'x': 148, 'y': 147}}],
#  'info': {'faceCount': 1, 'size': {'height': 495, 'width': 487}}}

# %%
alist = [17,24,22,22,20,20]
avg = round(sum(alist)/len(alist),2)
print(f'3팀의 평균연령은 {avg}입니다')
# Out:
# 3팀의 평균연령은 20.833입니다

# %%
team_dic = {'승혜':['이지민',24],'유진':['김아중',16],'지현':['서민정',22],'창익':['황규림',22],'혜원':['이윤지',20],'지선':['아이유',17]}
a = input('우리 3팀의:')
b_list = team_dic[a]
print(f'우리{a}님은 연예인 {b_list[0]}을(를) 닮았어요.')
print(f'얼굴 나이는{b_list[1]}! 대박대박!')
print(f'사랑스러운{a}님이시네요 ♥')
# Out:
# 우리 3팀의:창익
# 우리창익님은 연예인 황규림을(를) 닮았어요.
# 얼굴 나이는22! 대박대박!
# 사랑스러운창익님이시네요 ♥
